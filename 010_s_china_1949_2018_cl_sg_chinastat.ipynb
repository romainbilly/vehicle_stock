# %% [markdown]
# # Information regarding the data that this notebook refers to

# %% [markdown]
# # fill out the following fields. Check that input data and notebook name match.

# %%
notebook_id= '010'
name_string= '_s_china_1949_2018_cl_sg_chinastat'

nb_name= notebook_id + name_string +'.ipynb'
nb_input_workbook= 'in' + name_string + '.xlsx'
nb_output_workbook= notebook_id + '.xlsx'
nb_stock_or_flow= 'stock'
nb_geography= 'China'
nb_start_time= '1949'
nb_stop_time= '2018'
nb_attribute_1= 'class'
nb_attribute_2= 'registered'
nb_attribute_3= 'segment'
nb_attribute_4= ''
nb_data_source= 'NBSCHINA'
nb_data_source_url= 'http://www.stats.gov.cn/tjsj/ndsj/2019/indexeh.htm'
nb_comment= 'source describes change in category details see source metadata'

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib as plt
import pickle

# %%
# write the notbook metadata into a data frame
notebook_metadata = pd.DataFrame({'notebook_name':nb_name,
                                 'input_file': nb_input_workbook, 
                                 'output_file': nb_output_workbook, 
                                 'source': nb_data_source, 
                                 'geography': nb_geography,
                                 'start_time': nb_start_time,
                                 'stop_time': nb_stop_time, 
                                 'attribute1': nb_attribute_1, 
                                 'attribute2': nb_attribute_2,
                                 'attribute3': nb_attribute_3,
                                 'attribute4': nb_attribute_4,
                                 'source_url' : nb_data_source_url,
                                 'comment': nb_comment}, index=[notebook_id])

# %% [markdown]
# ## Reading in the excel data and merging the sheets into one dataframe with category info attached to row data

# %%
# read in data,
xls = pd.ExcelFile(nb_input_workbook)

# %%
df=pd.read_excel(xls, sheet_name= 'data')

# %%
df.tail()
# Out:
#                                                           class  \
# 010000002054                                              CHCOM
# 010000002055                                              CHCOM
# 010000002056                                              CHCOM
# 010000002057  Note: business vehicles only included those ow...
# 010000002058  Note: Since 2002, there has been adjustment to...
#
#                     segment     Unit  year  value year_of_measurement  \
# 010000002054            all  10000.0  2019    NaN                2019
# 010000002055  all passenger  10000.0  2019    NaN                2019
# 010000002056      all truck  10000.0  2019    NaN                2019
# 010000002057            NaN      NaN  2019    NaN                2019
# 010000002058            NaN      NaN  2019    NaN                2019
#
#              date_of_measurement    geo process  \
# 010000002054                      China       r
# 010000002055                      China       r
# 010000002056                      China       r
# 010000002057                      China       r
# 010000002058                      China       r
#
#                                                   vehicle_class  \
# 010000002054                                              CHCOM
# 010000002055                                              CHCOM
# 010000002056                                              CHCOM
# 010000002057  Note: business vehicles only included those ow...
# 010000002058  Note: Since 2002, there has been adjustment to...
#
#              vehicle_segment motor_energy model_year  \
# 010000002054             all          all        all
# 010000002055   all passenger          all        all
# 010000002056       all truck          all        all
# 010000002057             NaN          all        all
# 010000002058             NaN          all        all
#
#              year_of_first_registraion unit    source    accessed  \
# 010000002054                             nr  NBSCHINA  2020-08-04
# 010000002055                             nr  NBSCHINA  2020-08-04
# 010000002056                             nr  NBSCHINA  2020-08-04
# 010000002057                             nr  NBSCHINA  2020-08-04
# 010000002058                             nr  NBSCHINA  2020-08-04
#
#                                                  notebook  \
# 010000002054  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002055  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002056  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002057  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002058  010_s_china_1949_2018_cl_sg_chinastat.ipynb
#
#                                           footnote
# 010000002054  missing data means unknown, not zero
# 010000002055  missing data means unknown, not zero
# 010000002056  missing data means unknown, not zero
# 010000002057  missing data means unknown, not zero
# 010000002058  missing data means unknown, not zero

# %% [markdown]
#  #### replace class titles with codes

# %%
# read in the class_metatdata sheet which has equivalent terms for class types according to source
metaxls = pd.ExcelFile('metadata_vehicle_fleet.xlsx')
classMetadata = pd.read_excel(metaxls, sheet_name= 'class_metadata', index_col= 0)

# %%
classMetadata
# Out:
#         code                                     label  \
# id
# 1.0     EUM1                             passenger car
# 2.0     EUM2                                 light bus
# 3.0     EUM3                                 heavy bus
# 4.0     EUN1                  light commercial vehicle
# 5.0     EUN2                  heavy commercial vehicle
# 6.0     EUN3                           transport truck
# 7.0      EUL  motorcycles, tricycles, and quadracycles
# 8.0     OIPC                             passenger car
# 9.0     OICV                        commercial vehicle
# 10.0   USLDS      light duty vehicle, short wheel base
# 11.0   USBUS                                       bus
# 12.0   USLDL       Light duty vehicle, long wheel base
# 13.0   USTSU                               large truck
# 14.0   USTCO                         combination truck
# 15.0   USMCY                               motorcycle
# 16.0   INLVP          Light Motor Vehicles(Passengers)
# 17.0   INBUS                                    Buses
# 18.0   INTAX                                     Taxis
# 19.0   INGDV                         Goods vehicles(a)
# 20.0   INMCY                              Two-wheelers
# 21.0   INCAR                                      Cars
# 22.0   INJEP                                     Jeeps
# 23.0   INMSC                          Miscellaneous(b)
# 24.0    NOPC                              Private cars
# 25.0   NOAMB                                Ambulances
# 26.0   NOBUS                                     Buses
# NaN    NOVAN                                      Vans
# 27.0    NOLO                                   Lorries
# 28.0    NOCV                         Combines vehicles
# 29.0    NOTR                                  Tractors
# 30.0    NOMP                                    Mopeds
# 31.0   NOLMC                        Light motor cycles
# 32.0   NOHMC                        Heavy motor cycles
# 33.0    NOSS                              snow scooter
# 34.0    NOTL                                   trailer
# 35.0  CHPRIV                          private vehicles
# 36.0   CHCIV                            civil vehicles
# 37.0   CHCOM                         business vehicles
#
#                                             description  \
# id
# 1.0   Designed for the carriage of passengers, with ...
# 2.0   Designed for the carriage of passengers, carry...
# 3.0   Designed for the carriage of passengers, havin...
# 4.0   Designed for the carriage of goods, having a m...
# 5.0   Designed for the carriage of goods, having a m...
# 6.0   Designed for the carriage of goods, having a m...
# 7.0   Motor vehicles with less than four wheels and ...
# 8.0   Passenger cars are road motor vehicles, other ...
# 9.0   Commercial vehicles include light commercial v...
# 10.0  Light duty vehicle, short wheel base replaced ...
# 11.0  COMMERCIAL BUS: Any bus used to carry passenge...
# 12.0   Light duty vehicle, long wheel base replace t...
# 13.0  LARGE TRUCK: Trucks over 10,000 pounds gross v...
# 14.0  COMBINATION TRUCK: A power unit (truck tractor...
# 15.0  MOTORCYCLE: A two- or three-wheeled motor vehi...
# 16.0  Light Motor Vehicles(Passengers)means a transp...
# 17.0  omnibus means any motor vehicle constructed or...
# 18.0  Motor Cab means any motor vehicle constructed ...
# 19.0  Goods carriage means any motor vehicle contrac...
# 20.0  Motor Cycle means a two-wheeled motor vehicle,...
# 21.0                                no definition found
# 22.0                                no definition found
# 23.0                  includes Tractors/Trailers/Others
# 24.0  A private car is a car mainly with the purpose...
# 25.0  Motor vehicle specialised for transport of sic...
# 26.0  A bus is a vehicle for passenger transport wit...
# NaN   A van is a car for transport of goods with max...
# 27.0        A lorry is a vehicle for transport of goods
# 28.0  Vehicle mainly with the purpose of transportin...
# 29.0  A tractor is a motor vehicle mostly used for a...
# 30.0  Includes all kind of mopeds, both two wheel-, ...
# 31.0  A light motor cycle is a motorcycle with cylin...
# 32.0  Motor cycle with a cylinder capacity above 125...
# 33.0                                        Snowscooter
# 34.0  Vehicle mainly with the purpose of transportin...
# 35.0       not used for business or government purposes
# 36.0  includes private, agriculatural, commercial, a...
# 37.0          vehicles used for the commercial purposes
#
#                                                footnote              source  \
# id
# 1.0                                                 NaN  European Comission
# 2.0                                                 NaN  European Comission
# 3.0                                                 NaN  European Comission
# 4.0                                                 NaN  European Comission
# 5.0                                                 NaN  European Comission
# 6.0                                                 NaN  European Comission
# 7.0                                                 NaN  European Comission
# 8.0                                                 NaN                OICA
# 9.0                                                 NaN                OICA
# 10.0                                                NaN               USDOT
# 11.0                                                NaN               USDOT
# 12.0                                                NaN               USDOT
# 13.0                                                NaN               USDOT
# 14.0                                                NaN               USDOT
# 15.0                                                NaN               USDOT
# 16.0                                                NaN               MOSPI
# 17.0                                                NaN               MOSPI
# 18.0                                                NaN               MOSPI
# 19.0                                                NaN               MOSPI
# 20.0                                                NaN               MOSPI
# 21.0                                                NaN               MOSPI
# 22.0                                                NaN               MOSPI
# 23.0                                                NaN               MOSPI
# 24.0                                                NaN            STATBANK
# 25.0                                                NaN            STATBANK
# 26.0                                                NaN            STATBANK
# NaN                                                 NaN            STATBANK
# 27.0                                                NaN            STATBANK
# 28.0                                                NaN            STATBANK
# 29.0                                                NaN            STATBANK
# 30.0                                                NaN            STATBANK
# 31.0                                                NaN            STATBANK
# 32.0                                                NaN            STATBANK
# 33.0                                                NaN            STATBANK
# 34.0                                                NaN            STATBANK
# 35.0                                                NaN            NBSCHINA
# 36.0  private and business are believed to be includ...            NBSCHINA
# 37.0  Note: business vehicles only included those ow...            NBSCHINA
#
#                                             sourcelink1  \
# id
# 1.0   https://ec.europa.eu/growth/sectors/automotive...
# 2.0   https://ec.europa.eu/growth/sectors/automotive...
# 3.0   https://ec.europa.eu/growth/sectors/automotive...
# 4.0   https://ec.europa.eu/growth/sectors/automotive...
# 5.0   https://ec.europa.eu/growth/sectors/automotive...
# 6.0   https://ec.europa.eu/growth/sectors/automotive...
# 7.0   https://ec.europa.eu/growth/sectors/automotive...
# 8.0   http://www.oica.net/wp-content/uploads//DEFINI...
# 9.0   http://www.oica.net/wp-content/uploads//DEFINI...
# 10.0  https://www.bts.gov/content/number-us-aircraft...
# 11.0  https://www.bts.gov/content/number-us-aircraft...
# 12.0  https://www.bts.gov/content/number-us-aircraft...
# 13.0  https://www.bts.gov/content/number-us-aircraft...
# 14.0  https://www.bts.gov/content/number-us-aircraft...
# 15.0  https://www.bts.gov/content/number-us-aircraft...
# 16.0  http://mospi.nic.in/statistical-year-book-indi...
# 17.0  http://mospi.nic.in/statistical-year-book-indi...
# 18.0  http://mospi.nic.in/statistical-year-book-indi...
# 19.0  http://mospi.nic.in/statistical-year-book-indi...
# 20.0  http://mospi.nic.in/statistical-year-book-indi...
# 21.0  http://mospi.nic.in/statistical-year-book-indi...
# 22.0  http://mospi.nic.in/statistical-year-book-indi...
# 23.0  http://mospi.nic.in/statistical-year-book-indi...
# 24.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 25.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 26.0  https://www.ssb.no/a/metadata/conceptvariable/...
# NaN   https://www.ssb.no/a/metadata/conceptvariable/...
# 27.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 28.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 29.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 30.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 31.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 32.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 33.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 34.0  https://www.ssb.no/a/metadata/conceptvariable/...
# 35.0                  http://data.stats.gov.cn/english/
# 36.0                  http://data.stats.gov.cn/english/
# 37.0                  http://data.stats.gov.cn/english/
#
#                                             sourcelink2  Unnamed: 8  \
# id
# 1.0                                                 NaN         NaN
# 2.0                                                 NaN         NaN
# 3.0                                                 NaN         NaN
# 4.0                                                 NaN         NaN
# 5.0                                                 NaN         NaN
# 6.0                                                 NaN         NaN
# 7.0                                                 NaN         NaN
# 8.0                                                 NaN         NaN
# 9.0                                                 NaN         NaN
# 10.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 11.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 12.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 13.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 14.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 15.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 16.0                                                NaN         NaN
# 17.0                                                NaN         NaN
# 18.0                                                NaN         NaN
# 19.0                                                NaN         NaN
# 20.0                                                NaN         NaN
# 21.0                                                NaN         NaN
# 22.0                                                NaN         NaN
# 23.0                                                NaN         NaN
# 24.0                                                NaN         NaN
# 25.0                                                NaN         NaN
# 26.0                                                NaN         NaN
# NaN                                                 NaN         NaN
# 27.0                                                NaN         NaN
# 28.0                                                NaN         NaN
# 29.0                                                NaN         NaN
# 30.0                                                NaN         NaN
# 31.0                                                NaN         NaN
# 32.0                                                NaN         NaN
# 33.0                                                NaN         NaN
# 34.0                                                NaN         NaN
# 35.0                                                NaN         NaN
# 36.0                                                NaN         NaN
# 37.0                                                NaN         NaN
#
#       Unnamed: 9  Unnamed: 10 PCMO SML0  \
# id
# 1.0          NaN          NaN    p    m
# 2.0          NaN          NaN    c    l
# 3.0          NaN          NaN    c    l
# 4.0          NaN          NaN    c    m
# 5.0          NaN          NaN    c    l
# 6.0          NaN          NaN    c    l
# 7.0          NaN          NaN    m    s
# 8.0          NaN          NaN    p    m
# 9.0          NaN          NaN    c    l
# 10.0         NaN          NaN    p    m
# 11.0         NaN          NaN    c    l
# 12.0         NaN          NaN    p    m
# 13.0         NaN          NaN    c    l
# 14.0         NaN          NaN    c    l
# 15.0         NaN          NaN    m    s
# 16.0         NaN          NaN    p    m
# 17.0         NaN          NaN    c    l
# 18.0         NaN          NaN    p    m
# 19.0         NaN          NaN    c    l
# 20.0         NaN          NaN    m    s
# 21.0         NaN          NaN    p    m
# 22.0         NaN          NaN    p    m
# 23.0         NaN          NaN    o    o
# 24.0         NaN          NaN    p    p
# 25.0         NaN          NaN    c    m
# 26.0         NaN          NaN    c    m
# NaN          NaN          NaN    c    m
# 27.0         NaN          NaN    c    l
# 28.0         NaN          NaN    c    m
# 29.0         NaN          NaN    o    o
# 30.0         NaN          NaN    m    s
# 31.0         NaN          NaN    m    s
# 32.0         NaN          NaN    m    s
# 33.0         NaN          NaN    o    o
# 34.0         NaN          NaN    o    o
# 35.0         NaN          NaN  NaN  NaN
# 36.0         NaN          NaN  NaN  NaN
# 37.0         NaN          NaN  NaN  NaN
#
#                                  classification scheme3
# id
# 1.0                                                 NaN
# 2.0                                                 NaN
# 3.0                                                 NaN
# 4.0                                                 NaN
# 5.0                                                 NaN
# 6.0                                                 NaN
# 7.0                                                 NaN
# 8.0                                                 NaN
# 9.0                                                 NaN
# 10.0                                                NaN
# 11.0                                                NaN
# 12.0  It seems that this includes some of the large ...
# 13.0                                                NaN
# 14.0                                                NaN
# 15.0                                                NaN
# 16.0                                                NaN
# 17.0                                                NaN
# 18.0                                                NaN
# 19.0                                                NaN
# 20.0                                                NaN
# 21.0                                                NaN
# 22.0                                                NaN
# 23.0                                                NaN
# 24.0                                                NaN
# 25.0                                                NaN
# 26.0                                                NaN
# NaN                                                 NaN
# 27.0                                                NaN
# 28.0                                                NaN
# 29.0                                                NaN
# 30.0                                                NaN
# 31.0                                                NaN
# 32.0                                                NaN
# 33.0                                                NaN
# 34.0                                                NaN
# 35.0                                                NaN
# 36.0                                                NaN
# 37.0                                                NaN

# %%
# limit the data to the rows specific to relevent source
sourceClassDict= classMetadata[classMetadata.source == nb_data_source]

# %%
sourceClassDict
# Out:
#         code              label  \
# id
# 35.0  CHPRIV   private vehicles
# 36.0   CHCIV     civil vehicles
# 37.0   CHCOM  business vehicles
#
#                                             description  \
# id
# 35.0       not used for business or government purposes
# 36.0  includes private, agriculatural, commercial, a...
# 37.0          vehicles used for the commercial purposes
#
#                                                footnote    source  \
# id
# 35.0                                                NaN  NBSCHINA
# 36.0  private and business are believed to be includ...  NBSCHINA
# 37.0  Note: business vehicles only included those ow...  NBSCHINA
#
#                             sourcelink1 sourcelink2  Unnamed: 8  Unnamed: 9  \
# id
# 35.0  http://data.stats.gov.cn/english/         NaN         NaN         NaN
# 36.0  http://data.stats.gov.cn/english/         NaN         NaN         NaN
# 37.0  http://data.stats.gov.cn/english/         NaN         NaN         NaN
#
#       Unnamed: 10 PCMO SML0 classification scheme3
# id
# 35.0          NaN  NaN  NaN                    NaN
# 36.0          NaN  NaN  NaN                    NaN
# 37.0          NaN  NaN  NaN                    NaN

# %%
sourceClassLabel= sourceClassDict.label.to_list()

# %%
sourceClassCode = sourceClassDict.code.to_list()


df['class'].replace(to_replace=sourceClassLabel, value=sourceClassCode, inplace=True )

#find codes which did not match 
df.loc[~df['class'].isin(sourceClassCode)]
# Out:
#                                                 class segment  Unit  1949  \
# 27  Note: business vehicles only included those ow...     NaN   NaN   NaN
# 28  Note: Since 2002, there has been adjustment to...     NaN   NaN   NaN
#
#     1950  1951  1952  1953  1954  1955  ...  2010  2011  2012  2013  2014  \
# 27   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 28   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#     2015  2016  2017  2018  2019
# 27   NaN   NaN   NaN   NaN   NaN
# 28   NaN   NaN   NaN   NaN   NaN
#
# [2 rows x 74 columns]

# %% [markdown]
# ## rearrange data into proper format

# %%
df.head()
# Out:
#    class segment     Unit  1949  1950  1951  1952  1953  1954   1955  ...  \
# 0  CHCIV     all  10000.0  5.09  5.43  6.19  6.63  7.81  8.95  10.14  ...
#
#       2010     2011      2012      2013      2014      2015      2016  \
# 0  7801.83  9356.32  10933.09  12670.14  14598.11  16284.45  18574.54
#
#        2017      2018     2019
# 0  20906.67  23231.23  25387.2
#
# [1 rows x 74 columns]

# %%
#.melt() pivots the table bringing the column headers into a new attribute
melted = df.melt(id_vars=['class','segment','Unit'], var_name= 'year')
melted
# Out:
#                                                   class  \
# 0                                                 CHCIV
# 1                                                 CHCIV
# 2                                                 CHCIV
# 3                                                 CHCIV
# 4                                                 CHCIV
# ...                                                 ...
# 2054                                              CHCOM
# 2055                                              CHCOM
# 2056                                              CHCOM
# 2057  Note: business vehicles only included those ow...
# 2058  Note: Since 2002, there has been adjustment to...
#
#                         segment     Unit  year  value
# 0                           all  10000.0  1949   5.09
# 1                 all passenger  10000.0  1949   1.71
# 2      large passenger vehicles  10000.0  1949    NaN
# 3     medium passenger vehicles  10000.0  1949    NaN
# 4      small passenger vehicles  10000.0  1949    NaN
# ...                         ...      ...   ...    ...
# 2054                        all  10000.0  2019    NaN
# 2055              all passenger  10000.0  2019    NaN
# 2056                  all truck  10000.0  2019    NaN
# 2057                        NaN      NaN  2019    NaN
# 2058                        NaN      NaN  2019    NaN
#
# [2059 rows x 5 columns]

# %%
melted.value = 10000 * melted.value

# %% [markdown]
# ## structuring the data into format of datastructure

# %%
df = melted
df.head(2)
# Out:
#    class        segment     Unit  year    value
# 0  CHCIV            all  10000.0  1949  50900.0
# 1  CHCIV  all passenger  10000.0  1949  17100.0

# %%
# add in a column of indexes
df.index = notebook_id + df.index.astype(str).str.zfill(9)

# %%
#rename or add all necessary columns
df.loc[:,'year_of_measurement']= df.loc[:,'year']
# date of measurement is concatonated to year of measurement to achieve desired format
df.loc[:,'date_of_measurement']=''#df['year_of_measurement'].astype(str) + '-12-31'
df.head(2)
# Out:
#               class        segment     Unit  year    value  \
# 010000000000  CHCIV            all  10000.0  1949  50900.0
# 010000000001  CHCIV  all passenger  10000.0  1949  17100.0
#
#              year_of_measurement date_of_measurement
# 010000000000                1949
# 010000000001                1949

# %%
df.loc[:,'geo']= 'China'
df.loc[:,'process']= 'r'
df.loc[:,'vehicle_class']= df['class']
df.loc[:,'vehicle_segment']= df['segment']
df.loc[:,'motor_energy']= 'all'
df.loc[:,'model_year']= 'all'
df.loc[:,'year_of_first_registraion']=''
# df.loc[:,'value']= df['value']
df.loc[:,'unit']= 'nr'
df.loc[:,'source']= nb_data_source
df.loc[:,'accessed']= '2020-08-04'
df.loc[:,'notebook']= nb_name
df.loc[:,'footnote']= 'missing data means unknown, not zero'

# %%
# create a finalized dataframe for output with columns in arranged order
heading_list= ['year_of_measurement','date_of_measurement','geo','process','vehicle_class','vehicle_segment','motor_energy','model_year','year_of_first_registraion','value','unit','source','accessed','notebook','footnote']
df_out= df[heading_list]

# %%
#check df_out before saving
df_out
# Out:
#              year_of_measurement date_of_measurement    geo process  \
# 010000000000                1949                      China       r
# 010000000001                1949                      China       r
# 010000000002                1949                      China       r
# 010000000003                1949                      China       r
# 010000000004                1949                      China       r
# ...                          ...                 ...    ...     ...
# 010000002054                2019                      China       r
# 010000002055                2019                      China       r
# 010000002056                2019                      China       r
# 010000002057                2019                      China       r
# 010000002058                2019                      China       r
#
#                                                   vehicle_class  \
# 010000000000                                              CHCIV
# 010000000001                                              CHCIV
# 010000000002                                              CHCIV
# 010000000003                                              CHCIV
# 010000000004                                              CHCIV
# ...                                                         ...
# 010000002054                                              CHCOM
# 010000002055                                              CHCOM
# 010000002056                                              CHCOM
# 010000002057  Note: business vehicles only included those ow...
# 010000002058  Note: Since 2002, there has been adjustment to...
#
#                         vehicle_segment motor_energy model_year  \
# 010000000000                        all          all        all
# 010000000001              all passenger          all        all
# 010000000002   large passenger vehicles          all        all
# 010000000003  medium passenger vehicles          all        all
# 010000000004   small passenger vehicles          all        all
# ...                                 ...          ...        ...
# 010000002054                        all          all        all
# 010000002055              all passenger          all        all
# 010000002056                  all truck          all        all
# 010000002057                        NaN          all        all
# 010000002058                        NaN          all        all
#
#              year_of_first_registraion    value unit    source    accessed  \
# 010000000000                            50900.0   nr  NBSCHINA  2020-08-04
# 010000000001                            17100.0   nr  NBSCHINA  2020-08-04
# 010000000002                                NaN   nr  NBSCHINA  2020-08-04
# 010000000003                                NaN   nr  NBSCHINA  2020-08-04
# 010000000004                                NaN   nr  NBSCHINA  2020-08-04
# ...                                ...      ...  ...       ...         ...
# 010000002054                                NaN   nr  NBSCHINA  2020-08-04
# 010000002055                                NaN   nr  NBSCHINA  2020-08-04
# 010000002056                                NaN   nr  NBSCHINA  2020-08-04
# 010000002057                                NaN   nr  NBSCHINA  2020-08-04
# 010000002058                                NaN   nr  NBSCHINA  2020-08-04
#
#                                                  notebook  \
# 010000000000  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000001  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000002  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000003  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000004  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# ...                                                   ...
# 010000002054  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002055  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002056  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002057  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000002058  010_s_china_1949_2018_cl_sg_chinastat.ipynb
#
#                                           footnote
# 010000000000  missing data means unknown, not zero
# 010000000001  missing data means unknown, not zero
# 010000000002  missing data means unknown, not zero
# 010000000003  missing data means unknown, not zero
# 010000000004  missing data means unknown, not zero
# ...                                            ...
# 010000002054  missing data means unknown, not zero
# 010000002055  missing data means unknown, not zero
# 010000002056  missing data means unknown, not zero
# 010000002057  missing data means unknown, not zero
# 010000002058  missing data means unknown, not zero
#
# [2059 rows x 15 columns]

# %% [markdown]
# ## at this point restart kernel and run all cells

# %%
# write an output file named according to notebook id with relevant data and metadata
writer = pd.ExcelWriter(nb_output_workbook, engine='xlsxwriter')
df_out.to_excel(writer, sheet_name='data', merge_cells=False)
notebook_metadata.to_excel(writer, sheet_name= 'notebook_metadata')
writer.save()

# %%
# add the data from the notebook to the stock dataframe and notebook metadata pickles

import pickle
# load in the stock DataFrame pickle
stock_pickle = pd.read_pickle('stock_df.pickle')

# %%
# concatenate the out_df to the stock_pickle and remove any duplicate rows
stock_df = pd.concat([df_out,stock_pickle]).drop_duplicates(subset=['geo','notebook','source','value','year_of_measurement'])

# write the updated stock dataframe to pickle
stock_df.to_pickle('stock_df.pickle')

# repeat the process for the metadata
metadata_pickle = pd.read_pickle('metadata_df.pickle')

metadata_df = pd.concat([metadata_pickle, notebook_metadata]).drop_duplicates()

metadata_df.to_pickle('metadata_df.pickle')

# %%
# update the stock metadata 
writer = pd.ExcelWriter('vehicle_fleet_stock.xlsx', engine='xlsxwriter')
stock_df.to_excel(writer, sheet_name='data', merge_cells=False)
metadata_df.to_excel(writer, sheet_name= 'notebook_metadata')
writer.save()

# %%
stock_df
# Out:
#              year_of_measurement date_of_measurement  \
# 010000000000                1949
# 010000000001                1949
# 010000000002                1949
# 010000000006                1949
# 010000000011                1949
# ...                          ...                 ...
# 004000003800                2018
# 004000003801                2018
# 004000003803                2018
# 004000003804                2018
# 004000003806                2018
#
#                                                             geo process  \
# 010000000000                                              China       r
# 010000000001                                              China       r
# 010000000002                                              China       r
# 010000000006                                              China       r
# 010000000011                                              China       r
# ...                                                         ...     ...
# 004000003800                                             Sweden       r
# 004000003801  United Kingdom of Great Britain and Northern I...       r
# 004000003803                                             Norway       r
# 004000003804                                        Switzerland       r
# 004000003806                                             Turkey       r
#
#              vehicle_class           vehicle_segment motor_energy model_year  \
# 010000000000         CHCIV                       all          all        all
# 010000000001         CHCIV             all passenger          all        all
# 010000000002         CHCIV  large passenger vehicles          all        all
# 010000000006         CHCIV                 all truck          all        all
# 010000000011         CHCIV                     other          all        all
# ...                    ...                       ...          ...        ...
# 004000003800          EUM1                       all          ICE        all
# 004000003801          EUM1                       all          ICE        all
# 004000003803          EUM1                       all          ICE        all
# 004000003804          EUM1                       all          ICE        all
# 004000003806          EUM1                       all          ICE        all
#
#              year_of_first_registraion   value unit    source    accessed  \
# 010000000000                             50900   nr  NBSCHINA  2020-08-04
# 010000000001                             17100   nr  NBSCHINA  2020-08-04
# 010000000002                               NaN   nr  NBSCHINA  2020-08-04
# 010000000006                             32500   nr  NBSCHINA  2020-08-04
# 010000000011                              1300   nr  NBSCHINA  2020-08-04
# ...                                ...     ...  ...       ...         ...
# 004000003800                            212504   nr  EUROSTAT  2020-07-03
# 004000003801                               343   nr  EUROSTAT  2020-07-03
# 004000003803                              1008   nr  EUROSTAT  2020-07-03
# 004000003804                              3700   nr  EUROSTAT  2020-07-03
# 004000003806                             38815   nr  EUROSTAT  2020-07-03
#
#                                                  notebook  \
# 010000000000  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000001  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000002  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000006  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# 010000000011  010_s_china_1949_2018_cl_sg_chinastat.ipynb
# ...                                                   ...
# 004000003800  004_s_EU_2012_2018_cl(pc)_me_eurostat.ipynb
# 004000003801  004_s_EU_2012_2018_cl(pc)_me_eurostat.ipynb
# 004000003803  004_s_EU_2012_2018_cl(pc)_me_eurostat.ipynb
# 004000003804  004_s_EU_2012_2018_cl(pc)_me_eurostat.ipynb
# 004000003806  004_s_EU_2012_2018_cl(pc)_me_eurostat.ipynb
#
#                                                footnote
# 010000000000       missing data means unknown, not zero
# 010000000001       missing data means unknown, not zero
# 010000000002       missing data means unknown, not zero
# 010000000006       missing data means unknown, not zero
# 010000000011       missing data means unknown, not zero
# ...                                                 ...
# 004000003800                                        NaN
# 004000003801  definition differs, see eurostat metadata
# 004000003803                                        NaN
# 004000003804                                        NaN
# 004000003806  definition differs, see eurostat metadata
#
# [9570 rows x 15 columns]
