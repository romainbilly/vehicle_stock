# %% [markdown]
# # Information regarding the data that this notebook refers to

# %% [markdown]
# # fill out the following fields. Check that input data and notebook name match.
#
# # reference vehicle_fleet_data.xlsx notebook metadata to select notebook_id

# %%
notebook_id= '009'
name_string= '_s_NO_1950_2007_cl_statbank'

nb_name= notebook_id + name_string +'.ipynb'
nb_input_workbook= 'in' + name_string + '.xlsx'
nb_output_workbook= notebook_id + '.xlsx'
nb_stock_or_flow= 'stock'
nb_geography= 'Norway'
nb_start_time= '1950'
nb_stop_time= '2007'
nb_attribute_1= 'class'
nb_attribute_2= 'registered'
nb_attribute_3= ''
nb_attribute_4= ''
nb_data_source= 'STATBANK'
nb_data_source_url= 'https://www.ssb.no/en/statbank/table/01960/'
nb_comment= ''

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
# write the notbook metadata into a data frame
notebook_metadata = pd.DataFrame({'notebook_name':nb_name,
                                 'input_file': nb_input_workbook, 
                                 'output_file': nb_output_workbook, 
                                 'source': nb_data_source, 
                                 'geography': nb_geography,
                                 'start_time': nb_start_time,
                                 'stop_time': nb_stop_time, 
                                 'attribute1': nb_attribute_1, 
                                 'attribute2': nb_attribute_2,
                                 'attribute3': nb_attribute_3,
                                 'attribute4': nb_attribute_4,
                                 'source_url' : nb_data_source_url,
                                 'comment': nb_comment}, index=[notebook_id])

# %% [markdown]
# ## Reading in the excel data and merging the sheets into one dataframe with category info attached to row data

# %%
# read in data,
xls = pd.ExcelFile(nb_input_workbook)

# %%
# extract the data into a dataframe or several
df = pd.read_excel(xls, sheet_name= 'Personbiler1')
df
# Out:
#                       class   1950   1951   1952   1953    1954    1955  \
# 0            Passenger cars  65028  69509  78643  90771  108034  122143
# 1                     Buses   3797   3998   4207   4269    4499    4633
# 2                      Vans  15808  19519  25105  28917   30671   32597
# 3                   Lorries  31055  35880  39031  41219   44580   46956
# 4         Combined vehicles   1960   1892   1857   1932    1950    1920
# 5              Tractors etc   2140   3101   4291   5706    7700    8756
# 6  Special purpose vehicles     ..     ..     ..     ..      ..      ..
# 7                    Mopeds     ..     ..    826   1510    2770    7122
# 8        Light motor cycles   8162   8733   8593   8754   15545   17669
# 9        Heavy motor cycles  16768  18284  21239  27533   30086   36755
#
#      1956    1957    1958  ...     1998     1999     2000     2001     2002  \
# 0  134111  153391  172630  ...  1786404  1813642  1851929  1872862  1899767
# 1    4715    4860    4911  ...    36218    37039    36686    35667    34110
# 2   35515   40671   46135  ...   208955   219731   233248   249939   258133
# 3   47951   47938   48213  ...    74653    75959    76224    76414    77442
# 4    1936    2009    1990  ...   107221   107349   104868   100624    95453
# 5    8722    8646    8582  ...   215379   218287   220135   222805   225905
# 6      ..      ..      ..  ...     8705     8949     9069     9116     9086
# 7   14276   36789   55012  ...   113868   114868   115892   121159   130528
# 8   18418   19811   21197  ...     6389     7541     8785     9583    10510
# 9   42164   48515   52370  ...    64090    70592    76887    80685    84135
#
#       2003     2004     2005     2006     2007
# 0  1933660  1977922  2028909  2084193  2154837
# 1    32374    30592    28783    26954    25204
# 2   268326   284029   302956   331052   361911
# 3    79356    80623    82778    83609    84742
# 4    90600    85149    79705    73904    67020
# 5   229688   229265   231630   234243   237484
# 6     9038     8547     8361     8255     8208
# 7   140796   144855   148161   151670   156287
# 8    11521    12485    13630    14975    16589
# 9    87279    91231    95708   101900   109618
#
# [10 rows x 59 columns]

# %% [markdown]
#  #### replace class titles with codes

# %%
# read in the class_metatdata sheet which has equivalent terms for class types according to source
metaxls = pd.ExcelFile('metadata_vehicle_fleet.xlsx')
classMetadata = pd.read_excel(metaxls, sheet_name= 'class_metadata', index_col= 0)

# %%
classMetadata
# Out:
#        code                                     label  \
# id
# 1.0    EUM1                             passenger car
# 2.0    EUM2                                 light bus
# 3.0    EUM3                                 heavy bus
# 4.0    EUN1                  light commercial vehicle
# 5.0    EUN2                  heavy commercial vehicle
# 6.0    EUN3                           transport truck
# 7.0     EUL  motorcycles, tricycles, and quadracycles
# 8.0    OIPC                             passenger car
# 9.0    OICV                        commercial vehicle
# 10.0  USLDS      light duty vehicle, short wheel base
# 11.0  USBUS                                       bus
# 12.0  USLDL       Light duty vehicle, long wheel base
# 13.0  USTSU                               large truck
# 14.0  USTCO                         combination truck
# 15.0  USMCY                               motorcycle
# 16.0  INLVP          Light Motor Vehicles(Passengers)
# 17.0  INBUS                                    Buses
# 18.0  INTAX                                     Taxis
# 19.0  INGDV                         Goods vehicles(a)
# 20.0  INMCY                              Two-wheelers
# 21.0  INCAR                                      Cars
# 22.0  INJEP                                     Jeeps
# 23.0  INMSC                          Miscellaneous(b)
# 24.0   NOPC                              Private cars
# 25.0  NOAMB                                Ambulances
# 26.0  NOBUS                                     Buses
# NaN   NOVAN                                      Vans
# 27.0   NOLO                                   Lorries
# 28.0   NOCV                         Combines vehicles
# 29.0   NOTR                                  Tractors
# 30.0   NOMP                                    Mopeds
# 31.0  NOLMC                        Light motor cycles
# 32.0  NOHMC                        Heavy motor cycles
# 33.0   NOSS                              snow scooter
# 34.0   NOTL                                   trailer
#
#                                             description  footnote  \
# id
# 1.0   Designed for the carriage of passengers, with ...       NaN
# 2.0   Designed for the carriage of passengers, carry...       NaN
# 3.0   Designed for the carriage of passengers, havin...       NaN
# 4.0   Designed for the carriage of goods, having a m...       NaN
# 5.0   Designed for the carriage of goods, having a m...       NaN
# 6.0   Designed for the carriage of goods, having a m...       NaN
# 7.0   Motor vehicles with less than four wheels and ...       NaN
# 8.0   Passenger cars are road motor vehicles, other ...       NaN
# 9.0   Commercial vehicles include light commercial v...       NaN
# 10.0  Light duty vehicle, short wheel base replaced ...       NaN
# 11.0  COMMERCIAL BUS: Any bus used to carry passenge...       NaN
# 12.0   Light duty vehicle, long wheel base replace t...       NaN
# 13.0  LARGE TRUCK: Trucks over 10,000 pounds gross v...       NaN
# 14.0  COMBINATION TRUCK: A power unit (truck tractor...       NaN
# 15.0  MOTORCYCLE: A two- or three-wheeled motor vehi...       NaN
# 16.0  Light Motor Vehicles(Passengers)means a transp...       NaN
# 17.0  omnibus means any motor vehicle constructed or...       NaN
# 18.0  Motor Cab means any motor vehicle constructed ...       NaN
# 19.0  Goods carriage means any motor vehicle contrac...       NaN
# 20.0  Motor Cycle means a two-wheeled motor vehicle,...       NaN
# 21.0                                no definition found       NaN
# 22.0                                no definition found       NaN
# 23.0                  includes Tractors/Trailers/Others       NaN
# 24.0  A private car is a car mainly with the purpose...       NaN
# 25.0  Motor vehicle specialised for transport of sic...       NaN
# 26.0  A bus is a vehicle for passenger transport wit...       NaN
# NaN   A van is a car for transport of goods with max...       NaN
# 27.0        A lorry is a vehicle for transport of goods       NaN
# 28.0  Vehicle mainly with the purpose of transportin...       NaN
# 29.0  A tractor is a motor vehicle mostly used for a...       NaN
# 30.0  Includes all kind of mopeds, both two wheel-, ...       NaN
# 31.0  A light motor cycle is a motorcycle with cylin...       NaN
# 32.0  Motor cycle with a cylinder capacity above 125...       NaN
# 33.0                                        Snowscooter       NaN
# 34.0  Vehicle mainly with the purpose of transportin...       NaN
#
#                   source                                        sourcelink1  \
# id
# 1.0   European Comission  https://ec.europa.eu/growth/sectors/automotive...
# 2.0   European Comission  https://ec.europa.eu/growth/sectors/automotive...
# 3.0   European Comission  https://ec.europa.eu/growth/sectors/automotive...
# 4.0   European Comission  https://ec.europa.eu/growth/sectors/automotive...
# 5.0   European Comission  https://ec.europa.eu/growth/sectors/automotive...
# 6.0   European Comission  https://ec.europa.eu/growth/sectors/automotive...
# 7.0   European Comission  https://ec.europa.eu/growth/sectors/automotive...
# 8.0                 OICA  http://www.oica.net/wp-content/uploads//DEFINI...
# 9.0                 OICA  http://www.oica.net/wp-content/uploads//DEFINI...
# 10.0               USDOT  https://www.bts.gov/content/number-us-aircraft...
# 11.0               USDOT  https://www.bts.gov/content/number-us-aircraft...
# 12.0               USDOT  https://www.bts.gov/content/number-us-aircraft...
# 13.0               USDOT  https://www.bts.gov/content/number-us-aircraft...
# 14.0               USDOT  https://www.bts.gov/content/number-us-aircraft...
# 15.0               USDOT  https://www.bts.gov/content/number-us-aircraft...
# 16.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 17.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 18.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 19.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 20.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 21.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 22.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 23.0               MOSPI  http://mospi.nic.in/statistical-year-book-indi...
# 24.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 25.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 26.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# NaN             STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 27.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 28.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 29.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 30.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 31.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 32.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 33.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
# 34.0            STATBANK  https://www.ssb.no/a/metadata/conceptvariable/...
#
#                                             sourcelink2  Unnamed: 8  \
# id
# 1.0                                                 NaN         NaN
# 2.0                                                 NaN         NaN
# 3.0                                                 NaN         NaN
# 4.0                                                 NaN         NaN
# 5.0                                                 NaN         NaN
# 6.0                                                 NaN         NaN
# 7.0                                                 NaN         NaN
# 8.0                                                 NaN         NaN
# 9.0                                                 NaN         NaN
# 10.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 11.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 12.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 13.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 14.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 15.0  https://www.bts.gov/sites/bts.dot.gov/files/do...         NaN
# 16.0                                                NaN         NaN
# 17.0                                                NaN         NaN
# 18.0                                                NaN         NaN
# 19.0                                                NaN         NaN
# 20.0                                                NaN         NaN
# 21.0                                                NaN         NaN
# 22.0                                                NaN         NaN
# 23.0                                                NaN         NaN
# 24.0                                                NaN         NaN
# 25.0                                                NaN         NaN
# 26.0                                                NaN         NaN
# NaN                                                 NaN         NaN
# 27.0                                                NaN         NaN
# 28.0                                                NaN         NaN
# 29.0                                                NaN         NaN
# 30.0                                                NaN         NaN
# 31.0                                                NaN         NaN
# 32.0                                                NaN         NaN
# 33.0                                                NaN         NaN
# 34.0                                                NaN         NaN
#
#       Unnamed: 9  Unnamed: 10 PCMO SML0  \
# id
# 1.0          NaN          NaN    p    m
# 2.0          NaN          NaN    c    l
# 3.0          NaN          NaN    c    l
# 4.0          NaN          NaN    c    m
# 5.0          NaN          NaN    c    l
# 6.0          NaN          NaN    c    l
# 7.0          NaN          NaN    m    s
# 8.0          NaN          NaN    p    m
# 9.0          NaN          NaN    c    l
# 10.0         NaN          NaN    p    m
# 11.0         NaN          NaN    c    l
# 12.0         NaN          NaN    p    m
# 13.0         NaN          NaN    c    l
# 14.0         NaN          NaN    c    l
# 15.0         NaN          NaN    m    s
# 16.0         NaN          NaN    p    m
# 17.0         NaN          NaN    c    l
# 18.0         NaN          NaN    p    m
# 19.0         NaN          NaN    c    l
# 20.0         NaN          NaN    m    s
# 21.0         NaN          NaN    p    m
# 22.0         NaN          NaN    p    m
# 23.0         NaN          NaN    o    o
# 24.0         NaN          NaN    p    p
# 25.0         NaN          NaN    c    m
# 26.0         NaN          NaN    c    m
# NaN          NaN          NaN    c    m
# 27.0         NaN          NaN    c    l
# 28.0         NaN          NaN    c    m
# 29.0         NaN          NaN    o    o
# 30.0         NaN          NaN    m    s
# 31.0         NaN          NaN    m    s
# 32.0         NaN          NaN    m    s
# 33.0         NaN          NaN    o    o
# 34.0         NaN          NaN    o    o
#
#                                  classification scheme3
# id
# 1.0                                                 NaN
# 2.0                                                 NaN
# 3.0                                                 NaN
# 4.0                                                 NaN
# 5.0                                                 NaN
# 6.0                                                 NaN
# 7.0                                                 NaN
# 8.0                                                 NaN
# 9.0                                                 NaN
# 10.0                                                NaN
# 11.0                                                NaN
# 12.0  It seems that this includes some of the large ...
# 13.0                                                NaN
# 14.0                                                NaN
# 15.0                                                NaN
# 16.0                                                NaN
# 17.0                                                NaN
# 18.0                                                NaN
# 19.0                                                NaN
# 20.0                                                NaN
# 21.0                                                NaN
# 22.0                                                NaN
# 23.0                                                NaN
# 24.0                                                NaN
# 25.0                                                NaN
# 26.0                                                NaN
# NaN                                                 NaN
# 27.0                                                NaN
# 28.0                                                NaN
# 29.0                                                NaN
# 30.0                                                NaN
# 31.0                                                NaN
# 32.0                                                NaN
# 33.0                                                NaN
# 34.0                                                NaN

# %%
# limit the data to the rows specific to relevent source
sourceClassDF= classMetadata[classMetadata.source == nb_data_source]

# %%
sourceClassDF
# Out:
#        code               label  \
# id
# 24.0   NOPC        Private cars
# 25.0  NOAMB          Ambulances
# 26.0  NOBUS               Buses
# NaN   NOVAN                Vans
# 27.0   NOLO             Lorries
# 28.0   NOCV   Combines vehicles
# 29.0   NOTR            Tractors
# 30.0   NOMP              Mopeds
# 31.0  NOLMC  Light motor cycles
# 32.0  NOHMC  Heavy motor cycles
# 33.0   NOSS        snow scooter
# 34.0   NOTL             trailer
#
#                                             description  footnote    source  \
# id
# 24.0  A private car is a car mainly with the purpose...       NaN  STATBANK
# 25.0  Motor vehicle specialised for transport of sic...       NaN  STATBANK
# 26.0  A bus is a vehicle for passenger transport wit...       NaN  STATBANK
# NaN   A van is a car for transport of goods with max...       NaN  STATBANK
# 27.0        A lorry is a vehicle for transport of goods       NaN  STATBANK
# 28.0  Vehicle mainly with the purpose of transportin...       NaN  STATBANK
# 29.0  A tractor is a motor vehicle mostly used for a...       NaN  STATBANK
# 30.0  Includes all kind of mopeds, both two wheel-, ...       NaN  STATBANK
# 31.0  A light motor cycle is a motorcycle with cylin...       NaN  STATBANK
# 32.0  Motor cycle with a cylinder capacity above 125...       NaN  STATBANK
# 33.0                                        Snowscooter       NaN  STATBANK
# 34.0  Vehicle mainly with the purpose of transportin...       NaN  STATBANK
#
#                                             sourcelink1 sourcelink2  \
# id
# 24.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 25.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 26.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# NaN   https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 27.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 28.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 29.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 30.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 31.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 32.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 33.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
# 34.0  https://www.ssb.no/a/metadata/conceptvariable/...         NaN
#
#       Unnamed: 8  Unnamed: 9  Unnamed: 10 PCMO SML0 classification scheme3
# id
# 24.0         NaN         NaN          NaN    p    p                    NaN
# 25.0         NaN         NaN          NaN    c    m                    NaN
# 26.0         NaN         NaN          NaN    c    m                    NaN
# NaN          NaN         NaN          NaN    c    m                    NaN
# 27.0         NaN         NaN          NaN    c    l                    NaN
# 28.0         NaN         NaN          NaN    c    m                    NaN
# 29.0         NaN         NaN          NaN    o    o                    NaN
# 30.0         NaN         NaN          NaN    m    s                    NaN
# 31.0         NaN         NaN          NaN    m    s                    NaN
# 32.0         NaN         NaN          NaN    m    s                    NaN
# 33.0         NaN         NaN          NaN    o    o                    NaN
# 34.0         NaN         NaN          NaN    o    o                    NaN

# %%
sourceLabel= sourceClassDF.label.to_list()

# %%
sourceCode = sourceClassDF.code.to_list()


df['class'].replace(to_replace=sourceLabel, value=sourceCode, inplace=True )

#find codes which did not match 
df.loc[~df['class'].isin(sourceCode)]
# Out:
#                       class   1950   1951   1952   1953    1954    1955  \
# 0            Passenger cars  65028  69509  78643  90771  108034  122143
# 4         Combined vehicles   1960   1892   1857   1932    1950    1920
# 5              Tractors etc   2140   3101   4291   5706    7700    8756
# 6  Special purpose vehicles     ..     ..     ..     ..      ..      ..
#
#      1956    1957    1958  ...     1998     1999     2000     2001     2002  \
# 0  134111  153391  172630  ...  1786404  1813642  1851929  1872862  1899767
# 4    1936    2009    1990  ...   107221   107349   104868   100624    95453
# 5    8722    8646    8582  ...   215379   218287   220135   222805   225905
# 6      ..      ..      ..  ...     8705     8949     9069     9116     9086
#
#       2003     2004     2005     2006     2007
# 0  1933660  1977922  2028909  2084193  2154837
# 4    90600    85149    79705    73904    67020
# 5   229688   229265   231630   234243   237484
# 6     9038     8547     8361     8255     8208
#
# [4 rows x 59 columns]

# %% [markdown]
# ## rearrange data into proper format

# %%
df.head()
# Out:
#                class   1950   1951   1952   1953    1954    1955    1956  \
# 0     Passenger cars  65028  69509  78643  90771  108034  122143  134111
# 1              NOBUS   3797   3998   4207   4269    4499    4633    4715
# 2              NOVAN  15808  19519  25105  28917   30671   32597   35515
# 3               NOLO  31055  35880  39031  41219   44580   46956   47951
# 4  Combined vehicles   1960   1892   1857   1932    1950    1920    1936
#
#      1957    1958  ...     1998     1999     2000     2001     2002     2003  \
# 0  153391  172630  ...  1786404  1813642  1851929  1872862  1899767  1933660
# 1    4860    4911  ...    36218    37039    36686    35667    34110    32374
# 2   40671   46135  ...   208955   219731   233248   249939   258133   268326
# 3   47938   48213  ...    74653    75959    76224    76414    77442    79356
# 4    2009    1990  ...   107221   107349   104868   100624    95453    90600
#
#       2004     2005     2006     2007
# 0  1977922  2028909  2084193  2154837
# 1    30592    28783    26954    25204
# 2   284029   302956   331052   361911
# 3    80623    82778    83609    84742
# 4    85149    79705    73904    67020
#
# [5 rows x 59 columns]

# %%
#.melt() pivots the table bringing the column headers into a new attribute
melted = df.melt(id_vars=['class'], var_name= 'year')
melted
# Out:
#                         class  year   value
# 0              Passenger cars  1950   65028
# 1                       NOBUS  1950    3797
# 2                       NOVAN  1950   15808
# 3                        NOLO  1950   31055
# 4           Combined vehicles  1950    1960
# ..                        ...   ...     ...
# 575              Tractors etc  2007  237484
# 576  Special purpose vehicles  2007    8208
# 577                      NOMP  2007  156287
# 578                     NOLMC  2007   16589
# 579                     NOHMC  2007  109618
#
# [580 rows x 3 columns]

# %% [markdown]
# ## structuring the data into format of datastructure

# %%
#rename the data frame to df
df=melted
# add in a column of indexes
df.index = notebook_id + df.index.astype(str).str.zfill(9)

# %%
#rename or add all necessary columns
df.loc[:,'year_of_measurement']= df.loc[:,'year']
# date of measurement is concatonated to year of measurement to achieve desired format
df.loc[:,'date_of_measurement']=df['year_of_measurement'].astype(str) + '-12-31'
df.head(2)
# Out:
#                        class  year  value year_of_measurement  \
# 009000000000  Passenger cars  1950  65028                1950
# 009000000001           NOBUS  1950   3797                1950
#
#              date_of_measurement
# 009000000000          1950-12-31
# 009000000001          1950-12-31

# %%
df.loc[:,'geo']= 'Norway'
df.loc[:,'process']= 'r'
df.loc[:,'vehicle_class']= df['class']
df.loc[:,'vehicle_segment']='all'
df.loc[:,'motor_energy']= 'all'
df.loc[:,'model_year']= 'all'
df.loc[:,'year_of_first_registraion']=''
df.loc[:,'value']= df['value']
df.loc[:,'unit']= 'nr'
df.loc[:,'source']= nb_data_source
df.loc[:,'accessed']= '2020-08-04'
df.loc[:,'notebook']= nb_name
df.loc[:,'footnote']= ''

# %%
# create a finalized dataframe for output with columns in arranged order
heading_list= ['year_of_measurement','date_of_measurement','geo','process','vehicle_class','vehicle_segment','motor_energy','model_year','year_of_first_registraion','value','unit','source','accessed','notebook','footnote']
df_out= df[heading_list]

# %%
#check df_out before saving
df_out
# Out:
#              year_of_measurement date_of_measurement     geo process  \
# 009000000000                1950          1950-12-31  Norway       r
# 009000000001                1950          1950-12-31  Norway       r
# 009000000002                1950          1950-12-31  Norway       r
# 009000000003                1950          1950-12-31  Norway       r
# 009000000004                1950          1950-12-31  Norway       r
# ...                          ...                 ...     ...     ...
# 009000000575                2007          2007-12-31  Norway       r
# 009000000576                2007          2007-12-31  Norway       r
# 009000000577                2007          2007-12-31  Norway       r
# 009000000578                2007          2007-12-31  Norway       r
# 009000000579                2007          2007-12-31  Norway       r
#
#                          vehicle_class vehicle_segment motor_energy  \
# 009000000000            Passenger cars             all          all
# 009000000001                     NOBUS             all          all
# 009000000002                     NOVAN             all          all
# 009000000003                      NOLO             all          all
# 009000000004         Combined vehicles             all          all
# ...                                ...             ...          ...
# 009000000575              Tractors etc             all          all
# 009000000576  Special purpose vehicles             all          all
# 009000000577                      NOMP             all          all
# 009000000578                     NOLMC             all          all
# 009000000579                     NOHMC             all          all
#
#              model_year year_of_first_registraion   value unit    source  \
# 009000000000        all                             65028   nr  STATBANK
# 009000000001        all                              3797   nr  STATBANK
# 009000000002        all                             15808   nr  STATBANK
# 009000000003        all                             31055   nr  STATBANK
# 009000000004        all                              1960   nr  STATBANK
# ...                 ...                       ...     ...  ...       ...
# 009000000575        all                            237484   nr  STATBANK
# 009000000576        all                              8208   nr  STATBANK
# 009000000577        all                            156287   nr  STATBANK
# 009000000578        all                             16589   nr  STATBANK
# 009000000579        all                            109618   nr  STATBANK
#
#                 accessed                              notebook footnote
# 009000000000  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000001  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000002  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000003  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000004  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# ...                  ...                                   ...      ...
# 009000000575  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000576  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000577  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000578  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
# 009000000579  2020-08-04  009_s_NO_1950_2007_cl_statbank.ipynb
#
# [580 rows x 15 columns]

# %% [markdown]
# ## at this point restart kernel and run all cells

# %%
# write an output file named according to notebook id with relevant data and metadata
writer = pd.ExcelWriter(nb_output_workbook, engine='xlsxwriter')
df_out.to_excel(writer, sheet_name='data', merge_cells=False)
notebook_metadata.to_excel(writer, sheet_name= 'notebook_metadata')
writer.save()

# %%
# add the data from the notebook to the stock dataframe and notebook metadata pickles

import pickle
# load in the stock DataFrame pickle
stock_pickle = pd.read_pickle('stock_df.pickle')

# %%
# concatenate the out_df to the stock_pickle and remove any duplicate rows
stock_df = pd.concat([df_out,stock_pickle]).drop_duplicates(subset=['geo','notebook','source','value','year_of_measurement'])

# write the updated stock dataframe to pickle
stock_df.to_pickle('stock_df.pickle')

# repeat the process for the metadata
metadata_pickle = pd.read_pickle('metadata_df.pickle')

metadata_df = pd.concat([notebook_metadata,metadata_pickle]).drop_duplicates(subset= 'notebook_name' )

metadata_df.to_pickle('metadata_df.pickle')

# %%
# update the stock metadata 
writer = pd.ExcelWriter('vehicle_fleet_stock.xlsx', engine='xlsxwriter')
stock_df.to_excel(writer, sheet_name='data', merge_cells=False)
metadata_df.to_excel(writer, sheet_name= 'notebook_metadata')
writer.save()

# %%
stock_df.notebook.unique()
# Out:
# array(['009_s_NO_1950_2007_cl_statbank.ipynb',
#        '007_s_NO_2008_2015_cl_me_statbank.ipynb',
#        '003_s_GL_2005_2015_cl(cv)_oica.ipynb',
#        '006_s_IN_2001_2016_cl_inmorth.ipynb',
#        '008_s_NO_2016_2019_cl_me_statbank.ipynb',
#        '005_s_EU_1996_2018_cl(pc)_wt_eurostat.ipynb',
#        'oica_st_2005_2015_iu',
#        '004_s_EU_2012_2018_cl(pc)_me_eurostat.ipynb'], dtype=object)
